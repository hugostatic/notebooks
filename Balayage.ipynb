# %% [markdown]
# ```python
# def double_et_suivant(n):
#     return (2 * n, 2 * n + 1)
#
# print(double_et_suivant(2))
# (a, b) = double_et_suivant(502)
# print(a, b)
# ```

# %%
def double_et_suivant(n):
    return (2 * n, 2 * n + 1)

print(double_et_suivant(2))
(a, b) = double_et_suivant(502)
print(a, b)

# %% [markdown]
# Écrire une fonction **balayage(epsilon)** qui retourne un couple$(a,b)$ , tel que  $a$ et $b$  forment un encadrement de $\sqrt2$ d'amplitude epsilon : $a<\sqrt 2<b$ et $b-a=epsilon$ .
#
# Par exemple **print(balayage(0.1))** doit afficher : (1.4, 1.5)
