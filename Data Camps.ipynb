# %% [markdown]
# ## Méthodes

# %%
sister = 'liz'
print(sister)
# Out:
# liz

# %%
sister.replace('z','sa')
# Out:
# 'lisa'

# %%
print(sister)
# Out:
# liz

# %%
"Babar a dit : Le ciel est rose.".replace("rose","bleu")
# Out:
# 'Babar a dit : Le ciel est bleu.'
