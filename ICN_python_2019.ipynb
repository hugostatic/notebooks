# %% [markdown]
# ## Créer un compte sur France IOI
#
# http://www.france-ioi.org/algo/chapters.php
#
# parcours général
#
# 1. Affichage de texte, suite d'instructions : **exo de validation + challenges _les tours de Hanoĩ_ et _recette secrète_**
# 2. Répétitions d'instructions : **exo de validation + challenge _Le Grand Événement_ **

# %%
from robot import *
deplacer(1, 2)
deplacer(1, 3)
deplacer(2, 3)
deplacer(1, 2)
deplacer(3, 1)
deplacer(3, 2)
deplacer(1, 2)
deplacer(1, 3)
deplacer(2, 3)
deplacer(2, 1)
deplacer(3, 1)
deplacer(2, 3)
deplacer(1, 2)
deplacer(1, 3)
deplacer(2, 3)

# %%
from robot import *
remplir(5)
transferer(5, 3)
vider(3)
transferer(5, 3)
remplir(5)
transferer(5, 3)

# %%
from robot import *
for i in range(9):
   haut()
droite()
for j in range(4):
   for k in range(8):
      droite()
   bas()
   for l in range(8):
      gauche()
   bas()
for m in range(8):
   droite()
bas()
for n in range(9):
   gauche()
